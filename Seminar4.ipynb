# %%
import pandas as pd
df = pd.read_csv('./laptops_10.csv', sep=',')
df.head(1)
# Out:
#   Company      Product   TypeName  Inches                   Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  Intel Core i5 2.3GHz  8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
#
#    Memory_Amount Memory_Type
# 0          128.0         SSD

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,4))
plt.hist(df['Price_euros'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Example')
plt.xticks(rotation=30)
# Out:
# (array([-1000.,     0.,  1000.,  2000.,  3000.,  4000.,  5000.,  6000.,
#          7000.]),
#  [Text(-1000.0, 0, '−1000'),
#   Text(0.0, 0, '0'),
#   Text(1000.0, 0, '1000'),
#   Text(2000.0, 0, '2000'),
#   Text(3000.0, 0, '3000'),
#   Text(4000.0, 0, '4000'),
#   Text(5000.0, 0, '5000'),
#   Text(6000.0, 0, '6000'),
#   Text(7000.0, 0, '7000')])

# %%
plt.figure(figsize=(6,4))
plt.hist(df['Memory_Amount'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Memory')
plt.xticks(rotation=30);

# %%
plt.figure(figsize=(6,4))
plt.hist(df['Weight'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Count')
plt.xticks(rotation=30);

# %%
data = df['Memory_Type'].value_counts()

plt.pie(data.values, autopct='%1.2f%%',labels=data.index)

plt.legend('Count')
plt.title('Memory_Type')
plt.xticks(rotation=30);

# %%
data1 = df['Company'].value_counts()

plt.pie(data1.values, autopct='%1.2f%%',labels=data1.index)

plt.legend('Company')
plt.title('Memory_Type')
plt.xticks(rotation=30);

# %%
plt.bar(data1.index, data1.values)
plt.xticks(rotation=90);

# %%
data2 = df['OpSys'].value_counts()
plt.bar(data2.index, data2.values)
plt.xticks(rotation=90);

# %%
data3 = df['Cpu_Company'].value_counts()

plt.pie(data3.values, autopct='%1.2f%%',labels=data3.index)

plt.legend('Cpu_Company')
plt.title('Cpu_Company')
plt.xticks(rotation=90);

# %%
data4 = pd.crosstab(index=df['Company'],columns=df['Cpu_Company'])
data4 = data4.drop(columns=['Samsung']).reset_index()
data4
# Out:
# Cpu_Company    Company  AMD  Intel
# 0                 Acer   10     93
# 1                Apple    0     15
# 2                 Asus   11    147
# 3                Chuwi    0      1
# 4                 Dell    0    297
# 5              Fujitsu    0      3
# 6               Google    0      3
# 7                   HP   25    249
# 8               Huawei    0      2
# 9                   LG    0      3
# 10              Lenovo   16    281
# 11                 MSI    0     54
# 12            Mediacom    0      7
# 13           Microsoft    0      6
# 14               Razer    0      7
# 15             Samsung    0      8
# 16             Toshiba    0     48
# 17                Vero    0      4
# 18              Xiaomi    0      4

# %%
n_ticks = np.arange(len(data4['AMD']))
offset = 0.2
w = 0.4
plt.bar(n_ticks - offset, data4['AMD'],width = w)
plt.bar(n_ticks + offset, data4['Intel'],width = w)
plt.title('график ноутбуков')
plt.xlabel('company')
plt.ylabel('count')
plt.legend('amd','intel')
plt.xticks(n_ticks,data4['Company'],rotation=90);
# Out:
# C:\Users\Roman\AppData\Local\Temp\ipykernel_8800\3836061429.py:9: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries
#   plt.legend('amd','intel')
