# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./laptop_price.csv', sep=',', encoding='windows-1251')
df.head()
# Out:
#   laptop_ID Company      Product   TypeName  Inches  \
# 0         1   Apple  MacBook Pro  Ultrabook    13.3
# 1         2   Apple  Macbook Air  Ultrabook    13.3
# 2         3      HP       250 G6   Notebook    15.6
# 3         4   Apple  MacBook Pro  Ultrabook    15.4
# 4         5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
df.dtypes
# Out:
# laptop_ID            object
# Company              object
# Product              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price_euros         float64
# dtype: object

# %%
df.dropna(inplace=True)

# %%
df['Cpu_Company'] = 0
df.head()
df['Cpu_Company'] = df['Cpu'].apply(lambda x: x.split(" ")[0])
df.head()
# Out:
#   laptop_ID Company      Product   TypeName  Inches  \
# 0         1   Apple  MacBook Pro  Ultrabook    13.3
# 1         2   Apple  Macbook Air  Ultrabook    13.3
# 2         3      HP       250 G6   Notebook    15.6
# 3         4   Apple  MacBook Pro  Ultrabook    15.4
# 4         5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Cpu_Company
# 0      1339.69       Intel
# 1       898.94       Intel
# 2       575.00       Intel
# 3      2537.45       Intel
# 4      1803.60       Intel

# %%
def memory(memory_str):
    gb = memory_str.split(' ')[0]
    if gb.endswith('GB'):
        gb = float(gb[:-2])
    elif gb.endswith('TB'):
        gb = float(gb[:-2])*1024
    return gb
df['Memory_Amount'] = df['Memory'].apply(memory)
df.head()
# Out:
#   laptop_ID Company      Product   TypeName  Inches  \
# 0         1   Apple  MacBook Pro  Ultrabook    13.3
# 1         2   Apple  Macbook Air  Ultrabook    13.3
# 2         3      HP       250 G6   Notebook    15.6
# 3         4   Apple  MacBook Pro  Ultrabook    15.4
# 4         5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Cpu_Company  Memory_Amount
# 0      1339.69       Intel          128.0
# 1       898.94       Intel          128.0
# 2       575.00       Intel          256.0
# 3      2537.45       Intel          512.0
# 4      1803.60       Intel          256.0

# %%
df = pd.read_csv('./laptop_price.csv', sep=',', encoding='windows-1251')
df.head()
# Out:
#   laptop_ID Company      Product   TypeName  Inches  \
# 0         1   Apple  MacBook Pro  Ultrabook    13.3
# 1         2   Apple  Macbook Air  Ultrabook    13.3
# 2         3      HP       250 G6   Notebook    15.6
# 3         4   Apple  MacBook Pro  Ultrabook    15.4
# 4         5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
df.dropna(inplace=True)

# %%
df['Memory_Type'] = df['Memory'].apply(lambda x: x.split(" ")[1])
df.head()
# Out:
#   laptop_ID Company      Product   TypeName  Inches  \
# 0         1   Apple  MacBook Pro  Ultrabook    13.3
# 1         2   Apple  Macbook Air  Ultrabook    13.3
# 2         3      HP       250 G6   Notebook    15.6
# 3         4   Apple  MacBook Pro  Ultrabook    15.4
# 4         5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Memory_Type
# 0      1339.69         SSD
# 1       898.94       Flash
# 2       575.00         SSD
# 3      2537.45         SSD
# 4      1803.60         SSD

# %%
df.drop(columns=['Memory', 'ScreenResolution'], inplace=True)
df.head()

# %%
df.head()
# Out:
#   laptop_ID Company      Product   TypeName  Inches  \
# 0         1   Apple  MacBook Pro  Ultrabook    13.3
# 1         2   Apple  Macbook Air  Ultrabook    13.3
# 2         3      HP       250 G6   Notebook    15.6
# 3         4   Apple  MacBook Pro  Ultrabook    15.4
# 4         5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Memory_Type
# 0  1.37kg      1339.69         SSD
# 1  1.34kg       898.94       Flash
# 2  1.86kg       575.00         SSD
# 3  1.83kg      2537.45         SSD
# 4  1.37kg      1803.60         SSD

# %%
df['SSD']=0
df.head(1)
# Out:
#   laptop_ID Company      Product   TypeName  Inches  \
# 0         1   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                   Cpu  Ram     Memory  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz  8GB  128GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  SSD
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69    0

# %%
df.loc[df['Memory_Type'] == 'SSD', 'SSD'] = 1
df.head(1)
# Out:
#   laptop_ID Company      Product   TypeName  Inches                   Cpu  \
# 0         1   Apple  MacBook Pro  Ultrabook    13.3  Intel Core i5 2.3GHz
#
#    Ram                           Gpu  OpSys  Weight  Price_euros Memory_Type  \
# 0  8GB  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69         SSD
#
#    SSD
# 0    1

# %%
df['Weigth'] = df['Weight'].str.replace('kg','').astype('float')

df.head()
# Out:
#   laptop_ID Company      Product   TypeName  Inches  \
# 0         1   Apple  MacBook Pro  Ultrabook    13.3
# 1         2   Apple  Macbook Air  Ultrabook    13.3
# 2         3      HP       250 G6   Notebook    15.6
# 3         4   Apple  MacBook Pro  Ultrabook    15.4
# 4         5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Memory_Type  SSD  Weigth
# 0  1.37kg      1339.69         SSD    1    1.37
# 1  1.34kg       898.94       Flash    0    1.34
# 2  1.86kg       575.00         SSD    1    1.86
# 3  1.83kg      2537.45         SSD    1    1.83
# 4  1.37kg      1803.60         SSD    1    1.37

# %%
clients = pd.DataFrame({
 'client_id': [45, 32, 67, 33, 43],
 'laptop_id': [506, 398, 710, 120, 1999]
})
clients.head()
# Out:
#    client_id  laptop_id
# 0         45        506
# 1         32        398
# 2         67        710
# 3         33        120
# 4         43       1999

# %%
clients.dropna(inplace=True)

# %%
client_laptop = clients.set_index('laptop_id')
client_laptop.head()
# Out:
#            client_id
# laptop_id
# 506               45
# 398               32
# 710               67
# 120               33
# 1999              43

# %%
clients = pd.DataFrame({
 'client_id': [45, 32, 67, 33, 43],
 'laptop_id': [506, 398, 710, 120, 1999]
})
clients.head()
# Out:
#    client_id  laptop_id
# 0         45        506
# 1         32        398
# 2         67        710
# 3         33        120
# 4         43       1999

# %%
client_laptop.dtypes
# Out:
# client_id    int64
# dtype: object

# %%
df_laptop = df.set_index('laptop_ID')
df_laptop.head()
# Out:
#           Company      Product   TypeName  Inches  \
# laptop_ID
# 1           Apple  MacBook Pro  Ultrabook    13.3
# 2           Apple  Macbook Air  Ultrabook    13.3
# 3              HP       250 G6   Notebook    15.6
# 4           Apple  MacBook Pro  Ultrabook    15.4
# 5           Apple  MacBook Pro  Ultrabook    13.3
#
#                              ScreenResolution                         Cpu  \
# laptop_ID
# 1          IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 2                                    1440x900        Intel Core i5 1.8GHz
# 3                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 4          IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz
# 5          IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
#
#             Ram               Memory                           Gpu  OpSys  \
# laptop_ID
# 1           8GB            128GB SSD  Intel Iris Plus Graphics 640  macOS
# 2           8GB  128GB Flash Storage        Intel HD Graphics 6000  macOS
# 3           8GB            256GB SSD         Intel HD Graphics 620  No OS
# 4          16GB            512GB SSD            AMD Radeon Pro 455  macOS
# 5           8GB            256GB SSD  Intel Iris Plus Graphics 650  macOS
#
#            Weight  Price_euros  SSD
# laptop_ID
# 1          1.37kg      1339.69    0
# 2          1.34kg       898.94    0
# 3          1.86kg       575.00    0
# 4          1.83kg      2537.45    0
# 5          1.37kg      1803.60    0

# %%
df_laptop_join = client_laptop.join(df_laptop) 
df_laptop_join.head()
# Out:
#            client_id Company Product TypeName  Inches ScreenResolution  Cpu  \
# laptop_id
# 506               45     NaN     NaN      NaN     NaN              NaN  NaN
# 398               32     NaN     NaN      NaN     NaN              NaN  NaN
# 710               67     NaN     NaN      NaN     NaN              NaN  NaN
# 120               33     NaN     NaN      NaN     NaN              NaN  NaN
# 1999              43     NaN     NaN      NaN     NaN              NaN  NaN
#
#            Ram Memory  Gpu OpSys Weight  Price_euros  SSD
# laptop_id
# 506        NaN    NaN  NaN   NaN    NaN          NaN  NaN
# 398        NaN    NaN  NaN   NaN    NaN          NaN  NaN
# 710        NaN    NaN  NaN   NaN    NaN          NaN  NaN
# 120        NaN    NaN  NaN   NaN    NaN          NaN  NaN
# 1999       NaN    NaN  NaN   NaN    NaN          NaN  NaN

# %%
df_laptop_join.describe()
# Out:
#        client_id  Inches  Price_euros
# count   5.000000     0.0          0.0
# mean   44.000000     NaN          NaN
# std    14.106736     NaN          NaN
# min    32.000000     NaN          NaN
# 25%    33.000000     NaN          NaN
# 50%    43.000000     NaN          NaN
# 75%    45.000000     NaN          NaN
# max    67.000000     NaN          NaN

# %%
clients = pd.DataFrame({
 'client_id': [45, 32, 67, 33, 43],
 'laptop_id': [506, 398, 710, 120, 1999]
})

# %%
df = pd.read_csv('./laptop_price.csv', sep=',', encoding='windows-1251')
df.head()
# Out:
#   laptop_ID Company      Product   TypeName  Inches  \
# 0         1   Apple  MacBook Pro  Ultrabook    13.3
# 1         2   Apple  Macbook Air  Ultrabook    13.3
# 2         3      HP       250 G6   Notebook    15.6
# 3         4   Apple  MacBook Pro  Ultrabook    15.4
# 4         5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60
