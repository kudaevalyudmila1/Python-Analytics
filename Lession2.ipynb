# %%
import pandas as pd
import numpy as np
a = pd.Series([4, 7, 3, 6, 9],
              index = ['one', 'two','three','four', 'five'])
a
# Out:
# one      4
# two      7
# three    3
# four     6
# five     9
# dtype: int64

# %%
a = pd.Series([4, 7, 3, 6, 9])
a
# Out:
# 0    4
# 1    7
# 2    3
# 3    6
# 4    9
# dtype: int64

# %%
a.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
a.values
# Out:
# array([4, 7, 3, 6, 9], dtype=int64)

# %%
a[0]
# Out:
# 4

# %%
a = pd.Series([4, 7, 3, 6, 9],
              index = ['one', 'two','three','four', 'five'])
a['one']
# Out:
# 4

# %%
df =pd.DataFrame({
    'Age':[46,37,44,42,41],
    'Country':['Spain', 'Spain','Germany','France','Grmany'],
    'Gender':['f','f','f','m','m']
})
df
# Out:
#    Age  Country Gender
# 0   46    Spain      f
# 1   37    Spain      f
# 2   44  Germany      f
# 3   42   France      m
# 4   41   Grmany      m

# %%
df['Age']
# Out:
# 0    46
# 1    37
# 2    44
# 3    42
# 4    41
# Name: Age, dtype: int64

# %%
df.Country
# Out:
# 0      Spain
# 1      Spain
# 2    Germany
# 3     France
# 4     Grmany
# Name: Country, dtype: object

# %%
df[['Country','Age']]
# Out:
#    Country  Age
# 0    Spain   46
# 1    Spain   37
# 2  Germany   44
# 3   France   42
# 4   Grmany   41

# %%
df.columns
# Out:
# Index(['Age', 'Country', 'Gender'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df =pd.DataFrame({
    'Age':[46,37,44,42,41],
    'Country':['Spain', 'Spain','Germany','France','Grmany'],
    'Gender':['f','f','f','m','m']
}, index =[5,4,6,3,2])
df
# Out:
#    Age  Country Gender
# 5   46    Spain      f
# 4   37    Spain      f
# 6   44  Germany      f
# 3   42   France      m
# 2   41   Grmany      m

# %%
df.index = [101,102,103,104,105]
df
# Out:
#      Age  Country Gender
# 101   46    Spain      f
# 102   37    Spain      f
# 103   44  Germany      f
# 104   42   France      m
# 105   41   Grmany      m

# %%
df = pd.read_csv('./Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
pd.read_csv('./Churn_Modelling.csv',sep=';')
# Out:
#      RowNumber,CustomerId,Surname,CreditScore,Geography,Gender,Age,Tenure,Balance,NumOfProducts,HasCrCard,IsActiveMember,EstimatedSalary,Exited
# 0     1,15634602,Hargrave,619,France,Female,42,2,0,1...
# 1     2,15647311,Hill,608,Spain,Female,41,1,83807.86...
# 2     3,15619304,Onio,502,France,Female,42,8,159660....
# 3     4,15701354,Boni,699,France,Female,39,1,0,2,0,0...
# 4     5,15737888,Mitchell,850,Spain,Female,43,2,1255...
# ...                                                 ...
# 9995  9996,15606229,Obijiaku,771,France,Male,39,5,0,...
# 9996  9997,15569892,Johnstone,516,France,Male,35,10,...
# 9997  9998,15584532,Liu,709,France,Female,36,7,0,1,0...
# 9998  9999,15682355,Sabbatini,772,Germany,Male,42,3,...
# 9999  10000,15628319,Walker,792,France,Female,28,4,1...
#
# [10000 rows x 1 columns]

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.sample()
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography  Gender  Age  \
# 6194       6195    15794273    Hand          604    France  Female   56
#
#       Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 6194       0  62732.65              1          0               1
#
#       EstimatedSalary  Exited
# 6194        124954.56       0

# %%
df.sample(frac=1)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 811         812    15649992  Alexander          681     Spain    Male   65
# 6736       6737    15771299  Nnachetam          707    France  Female   57
# 8075       8076    15745250    Simpson          850    France    Male   58
# 7612       7613    15599535     Howell          678     Spain    Male   28
# 9860       9861    15716431    Brookes          775    France  Female   30
# ...         ...         ...        ...          ...       ...     ...  ...
# 7384       7385    15589881       Rowe          634    France  Female   41
# 2449       2450    15567980     Frater          537   Germany  Female   46
# 6587       6588    15705313     Stange          707    France  Female   33
# 6790       6791    15599074         Ma          487     Spain  Female   40
# 9079       9080    15730488   Richmond          516     Spain  Female   27
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.sample(frac=0.5)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 409         410    15691625         Ko          537   Germany  Female   41
# 7570       7571    15791944     Harker          697    France    Male   32
# 8962       8963    15607874      Keane          687    France    Male   38
# 9878       9879    15770041      Manna          728     Spain  Female   43
# 8731       8732    15769125    Palerma          727     Spain  Female   41
# ...         ...         ...        ...          ...       ...     ...  ...
# 5263       5264    15745030  Trevisano          809   Germany    Male   41
# 8437       8438    15591428      Myers          781    France    Male   29
# 685         686    15600337      Dobie          661     Spain    Male   42
# 4409       4410    15781598  Middleton          756   Germany    Male   41
# 7398       7399    15577771   Akabueze          453   Germany  Female   40
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df['Age'].min()
# Out:
# 18

# %%
df['Age'].max()
# Out:
# 92

# %%
df[['Age','Tenure']].mean()
# Out:
# Age       38.9218
# Tenure     5.0128
# dtype: float64

# %%
df.describe(include=['object'])
# Out:
#        Surname Geography Gender
# count    10000     10000  10000
# unique    2932         3      2
# top      Smith    France   Male
# freq        32      5014   5457

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df['Age'].dtype
# Out:
# dtype('int64')

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Geography'].nunique()
# Out:
# 3

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df['Geography'].value_counts(normalize=True)
# Out:
# France     0.5014
# Germany    0.2509
# Spain      0.2477
# Name: Geography, dtype: float64

# %%
df['Gender']=='Male'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999    False
# Name: Gender, Length: 10000, dtype: bool

# %%
male=df[df['Gender']=='Male']
male
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography Gender  Age  \
# 5             6    15574012          Chu          645     Spain   Male   44
# 6             7    15592531     Bartlett          822    France   Male   50
# 8             9    15792365           He          501    France   Male   44
# 9            10    15592389           H?          684    France   Male   27
# 10           11    15767821       Bearce          528    France   Male   31
# ...         ...         ...          ...          ...       ...    ...  ...
# 9992       9993    15657105  Chukwualuka          726     Spain   Male   36
# 9993       9994    15569266       Rahman          644    France   Male   28
# 9995       9996    15606229     Obijiaku          771    France   Male   39
# 9996       9997    15569892    Johnstone          516    France   Male   35
# 9998       9999    15682355    Sabbatini          772   Germany   Male   42
#
# ...

# %%
df[(df['Gender']=='Female')&(df['NumOfProducts'] >= 3)]
# Out:
#       RowNumber  CustomerId        Surname  CreditScore Geography  Gender  \
# 2             3    15619304           Onio          502    France  Female
# 7             8    15656148         Obinna          376   Germany  Female
# 30           31    15589475        Azikiwe          591     Spain  Female
# 88           89    15622897         Sharpe          646    France  Female
# 90           91    15757535           Heap          647     Spain  Female
# ...         ...         ...            ...          ...       ...     ...
# 9565       9566    15752294           Long          582    France  Female
# 9747       9748    15775761  Iweobiegbunam          610   Germany  Female
# 9800       9801    15640507             Li          762     Spain  Female
# 9877       9878    15572182     Onwuamaeze          505   Germany  Female
# 9895       9896    15796764          Bruno          684   Germany  Female
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[(df['HasCrCard'])|(df['NumOfProducts'] >=3)]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 4             5    15737888   Mitchell          850     Spain  Female   43
# 5             6    15574012        Chu          645     Spain    Male   44
# 6             7    15592531   Bartlett          822    France    Male   50
# ...         ...         ...        ...          ...       ...     ...  ...
# 9993       9994    15569266     Rahman          644    France    Male   28
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[~(df['Geography']=='Spain')]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 7             8    15656148     Obinna          376   Germany  Female   29
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[df['Geography'].isin(['France','Germany'])]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 7             8    15656148     Obinna          376   Germany  Female   29
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_s =df[(df['Geography']=='Spain')][['Geography','Gender','Age']]
df_s.head()
# Out:
#    Geography  Gender  Age
# 1      Spain  Female   41
# 4      Spain  Female   43
# 5      Spain    Male   44
# 11     Spain    Male   24
# 14     Spain  Female   35

# %%
df_s.loc[1]
# Out:
# Geography     Spain
# Gender       Female
# Age              41
# Name: 1, dtype: object

# %%
df_s.loc[[1,4,5],['Gender','Age']]
# Out:
#    Gender  Age
# 1  Female   41
# 4  Female   43
# 5    Male   44

# %%
df_s.iloc[[1,4,5]]
# Out:
#    Geography  Gender  Age
# 4      Spain  Female   43
# 14     Spain  Female   35
# 17     Spain  Female   24

# %%
df_s.iloc[0,[0,2]]
# Out:
# Geography    Spain
# Age             41
# Name: 1, dtype: object

# %%
df.sort_values('Age')
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3512       3513    15657779       Boylan          806     Spain    Male   18
# 1678       1679    15569178    Kharlamov          570    France  Female   18
# 3517       3518    15757821      Burgess          771     Spain    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 2021       2022    15795519     Vasiliev          716   Germany  Female   18
# ...         ...         ...          ...          ...       ...     ...  ...
# 3387       3388    15798024         Lori          537   Germany    Male   84
# 3033       3034    15578006          Yao          787    France  Female   85
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 6759       6760    15660878        T'ien          705    France    Male   92
# 6443       6444    15764927       Rogova          753    France    Male   92
#
# ...

# %%
df.sort_values('Age',ascending=False)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 6443       6444    15764927       Rogova          753    France    Male   92
# 6759       6760    15660878        T'ien          705    France    Male   92
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 3033       3034    15578006          Yao          787    France  Female   85
# 3387       3388    15798024         Lori          537   Germany    Male   84
# ...         ...         ...          ...          ...       ...     ...  ...
# 9782       9783    15728829       Weigel          509    France    Male   18
# 2141       2142    15758372      Wallace          674    France    Male   18
# 9501       9502    15634146          Hou          835   Germany    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 1619       1620    15770309     McDonald          656    France    Male   18
#
# ...

# %%
df.sort_values(['Age','CreditScore'])
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 9782       9783    15728829           Weigel          509    France    Male
# 1678       1679    15569178        Kharlamov          570    France  Female
# 9029       9030    15722701            Bruno          594   Germany    Male
# 7334       7335    15759133          Vaguine          616    France    Male
# 9526       9527    15665521  Chiazagomekpele          642   Germany    Male
# ...         ...         ...              ...          ...       ...     ...
# 3387       3388    15798024             Lori          537   Germany    Male
# 3033       3034    15578006              Yao          787    France  Female
# 2458       2459    15813303          Rearick          513     Spain    Male
# 6759       6760    15660878            T'ien          705    France    Male
# 6443       6444    15764927           Rogova          753    France    Male
#
# ...

# %%
df['new_feature'] = 0
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature
# 0        101348.88       1            0
# 1        112542.58       0            0
# ...

# %%
df['Age (days)'] = df['Age'] * 365
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)
# 0        101348.88       1            0       15330
# 1        112542.58       0            0       14965
# ...

# %%
for i, row in df.iloc[:2].iterrows():
    print(row)
    print('__' * 30)
# Out:
# RowNumber                  1
# CustomerId          15634602
# Surname             Hargrave
# CreditScore              619
# Geography             France
# Gender                Female
# Age                       42
# Tenure                     2
# Balance                  0.0
# NumOfProducts              1
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    101348.88
# Exited                     1
# new_feature                0
# Age (days)             15330
# Name: 0, dtype: object
# ____________________________________________________________
# RowNumber                  2
# CustomerId          15647311
# Surname                 Hill
# CreditScore              608
# Geography              Spain
# Gender                Female
# Age                       41
# Tenure                     1
# Balance             83807.86
# NumOfProducts              1
# HasCrCard                  0
# IsActiveMember             1
# EstimatedSalary    112542.58
# ...

# %%
age_days = []

for i, row in df.iterrows():
    age_days.append(row['Age'] * 365)

age_days[:10]
# Out:
# [15330, 14965, 15330, 14235, 15695, 16060, 18250, 10585, 16060, 9855]

# %%
df['Age (days) 2'] = age_days
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)  Age (days) 2
# 0        101348.88       1            0       15330         15330
# ...

# %%
def age_to_days(x):
    return x * 365

df['Age (days) 3'] = df['Age'].apply(age_to_days)
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)  Age (days) 2  \
# 0        101348.88       1            0       15330         15330
# ...

# %%
import time
from tqdm import tqdm
tqdm.pandas()


def age_to_days(x):
    time.sleep(0.001)
    return x * 365

df['Age'].progress_apply(age_to_days)
# Out:
# 100%|██████████| 10000/10000 [00:17<00:00, 557.56it/s]
# 0       15330
# 1       14965
# 2       15330
# 3       14235
# 4       15695
#         ...
# 9995    14235
# 9996    12775
# 9997    13140
# 9998    15330
# 9999    10220
# Name: Age, Length: 10000, dtype: int64

# %%
df.drop(columns='new_feature')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)  Age (days) 2  \
# 0        101348.88       1            0       15330         15330
# ...

# %%
df = df.drop(columns='new_feature')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Age (days)  Age (days) 2  Age (days) 3
# 0        101348.88       1       15330         15330         15330
# ...

# %%
df['new_feature'] = 0
df.drop(columns='new_feature', inplace=True)
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Age (days)  Age (days) 2  Age (days) 3
# 0        101348.88       1       15330         15330         15330
# ...

# %%
df.drop(columns=['Age (days)', 'Age (days) 2', 'Age (days) 3'], inplace=True)
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df['target'] = 0
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  target
# 0        101348.88       1       0
# 1        112542.58       0       0
# 2        113931.57       1       0
# ...

# %%
df.loc[df['Geography'] == 'France']
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 8             9    15792365         He          501    France    Male   44
# ...         ...         ...        ...          ...       ...     ...  ...
# 9994       9995    15719294       Wood          800    France  Female   29
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.loc[df['Geography'] == 'France', 'target']
# Out:
# 0       0
# 2       0
# 3       0
# 6       0
# 8       0
#        ..
# 9994    0
# 9995    0
# 9996    0
# 9997    0
# 9999    0
# Name: target, Length: 5014, dtype: int64

# %%
df[df['Geography'] == 'France']['target'] = 1
df.head()
# Out:
# C:\Users\Roman\AppData\Local\Temp\ipykernel_12584\1093803703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Geography'] == 'France']['target'] = 1
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
df.loc[df['Geography'] == 'France', 'target'] = 1
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  target
# 0        101348.88       1       1
# 1        112542.58       0       0
# 2        113931.57       1       1
# ...

# %%
df['Gender'].replace({'Female': 'F', 'Male': 'M'}, inplace=True)
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography Gender  Age  Tenure  \
# 0          1    15634602  Hargrave          619    France      F   42       2
# 1          2    15647311      Hill          608     Spain      F   41       1
# 2          3    15619304      Onio          502    France      F   42       8
# 3          4    15701354      Boni          699    France      F   39       1
# 4          5    15737888  Mitchell          850     Spain      F   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited  target
# 0       1       1
# 1       0       0
# ...

# %%
df['Age'].agg(['min', 'max'])
# Out:
# min    18
# max    92
# Name: Age, dtype: int64

# %%
df.agg({
    'Age': ['min', 'max'],
    'EstimatedSalary': 'mean'
})
# Out:
#        Age  EstimatedSalary
# min   18.0              NaN
# max   92.0              NaN
# mean   NaN    100090.239881

# %%
df.agg(
    min_age=('Age', 'min'),
    max_age=('Age', 'max'),
    mean_salary=('EstimatedSalary', 'mean')
)
# Out:
#               Age  EstimatedSalary
# min_age      18.0              NaN
# max_age      92.0              NaN
# mean_salary   NaN    100090.239881

# %%
merged = users.merge(bank, left_on='CustomerId', right_on='CustomerId')
merged.head()

# %%
toy_df1 = pd.DataFrame({
    'col_1': [1, 2, 3],
    'col_2': [9, 9, 9]
})

toy_df2 = pd.DataFrame({
    'col_1': [3, 4],
    'col_3': [0, 0]
})

display(toy_df1, toy_df2)
# Out:
#    col_1  col_2
# 0      1      9
# 1      2      9
# 2      3      9
#    col_1  col_3
# 0      3      0
# 1      4      0

# %%
toy_df1.merge(toy_df2, how='left')
# Out:
#    col_1  col_2  col_3
# 0      1      9    NaN
# 1      2      9    NaN
# 2      3      9    0.0

# %%
toy_df1.merge(toy_df2, how='right')
# Out:
#    col_1  col_2  col_3
# 0      3    9.0      0
# 1      4    NaN      0

# %%
toy_df1.merge(toy_df2, how='inner')
# Out:
#    col_1  col_2  col_3
# 0      3      9      0

# %%
toy_df1.merge(toy_df2, how='outer')
# Out:
#    col_1  col_2  col_3
# 0      1    9.0    NaN
# 1      2    9.0    NaN
# 2      3    9.0    0.0
# 3      4    NaN    0.0

# %%
toy_df = pd.DataFrame({
    'client_id': [1, 2, 2, 3, 1, 1],
    'item': ['chocolate', 'cheese', 'ham', 'candy', 'chair', 'book'],
    'price': [68, 280, 302, 39, 2099, 1089]
})

toy_df
# Out:
#    client_id       item  price
# 0          1  chocolate     68
# 1          2     cheese    280
# 2          2        ham    302
# 3          3      candy     39
# 4          1      chair   2099
# 5          1       book   1089

# %%
grouped = toy_df.groupby('client_id')
grouped

# %%
grouped.groups
# Out:
# {1: [0, 4, 5], 2: [1, 2], 3: [3]}

# %%
grouped.sum()
# Out:
# C:\Users\Roman\AppData\Local\Temp\ipykernel_12584\2368404282.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped.sum()
#            price
# client_id
# 1           3256
# 2            582
# 3             39

# %%
grouped.agg({'price': ['sum', 'min', 'max']})
# Out:
#           price
#             sum  min   max
# client_id
# 1          3256   68  2099
# 2           582  280   302
# 3            39   39    39

# %%
df.groupby('Geography').agg({'Age': ['mean'], 'EstimatedSalary': ['min']})
# Out:
#                  Age EstimatedSalary
#                 mean             min
# Geography
# France     38.511767           90.07
# Germany    39.771622           11.58
# Spain      38.890997          417.41

# %%
toy_df
# Out:
#    client_id       item  price
# 0          1  chocolate     68
# 1          2     cheese    280
# 2          2        ham    302
# 3          3      candy     39
# 4          1      chair   2099
# 5          1       book   1089

# %%
toy_df.pivot_table(index='client_id',
                   values='price',
                   aggfunc='sum')
# Out:
#            price
# client_id
# 1           3256
# 2            582
# 3             39

# %%
df.pivot_table(index='Geography',
                  aggfunc={'Age': ['mean'], 'EstimatedSalary': 'min'})
# Out:
#                  Age EstimatedSalary
#                 mean             min
# Geography
# France     38.511767           90.07
# Germany    39.771622           11.58
# Spain      38.890997          417.41

# %%
df.pivot_table(index='Geography',
                  columns='Gender', 
                  values='EstimatedSalary',
                  aggfunc='mean',
                  margins=True,
                  margins_name='Total')
# Out:
# Gender                 F              M          Total
# Geography
# France      99564.252755  100174.252495   99899.180814
# Germany    102446.424124   99905.033959  101113.435102
# Spain      100734.107475   98425.687680   99440.572281
# Total      100601.541382   99664.576931  100090.239881

# %%
pd.crosstab(index=df['Geography'],
            columns=df['Gender'])
# Out:
# Gender        F     M
# Geography
# France     2261  2753
# Germany    1193  1316
# Spain      1089  1388

# %%
pd.crosstab(index=df['Geography'],
            columns=df['Gender'],
            values=df['EstimatedSalary'],
            aggfunc='mean')
# Out:
# Gender                 F              M
# Geography
# France      99564.252755  100174.252495
# Germany    102446.424124   99905.033959
# Spain      100734.107475   98425.687680

# %%
pd.crosstab(index=df['Geography'],
            columns=df['Gender'],
            normalize='all')
# Out:
# Gender          F       M
# Geography
# France     0.2261  0.2753
# Germany    0.1193  0.1316
# Spain      0.1089  0.1388

# %%
pd.crosstab(index=df['Geography'],
            columns=df['Gender'],
            normalize='index')
# Out:
# Gender            F         M
# Geography
# France     0.450937  0.549063
# Germany    0.475488  0.524512
# Spain      0.439645  0.560355

# %%
pd.crosstab(index=df['Geography'],
            columns=df['Gender'],
            normalize='columns')
# Out:
# Gender            F         M
# Geography
# France     0.497689  0.504490
# Germany    0.262602  0.241158
# Spain      0.239709  0.254352

# %%
df['Age'].hist();

# %%
data = df.groupby('Gender').count()['Age']
data.name = 'Gender'
data
# Out:
# Gender
# F    4543
# M    5457
# Name: Gender, dtype: int64

# %%
data.plot.pie(y='Gender');

# %%
df.iloc[:100].plot.scatter(x='Age', y='EstimatedSalary');

# %%
data = df.groupby('Tenure').count()['Balance']
data.name = 'num_clients'
data
# Out:
# Tenure
# 0      413
# 1     1035
# 2     1048
# 3     1009
# 4      989
# 5     1012
# 6      967
# 7     1028
# 8     1025
# 9      984
# 10     490
# Name: num_clients, dtype: int64

# %%
data.plot.bar(width=0.8);
